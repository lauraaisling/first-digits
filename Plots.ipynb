# %% [markdown]
# Plots.ipynb

# %% [markdown]
# Data directories:

# %%
######################### Insert_here

# %%
base_dir = base_dir_path
IMAGENET_C_data = IMAGENET_C_data_path
Subcategory_IMAGENET_C_files = Subcategory_IMAGENET_C_files_path

bench_JSs_DCT_f = f"{base_dir_path}{Subcategory_IMAGENET_C_files_path}/Divergences/bench_JSs_DCT.pkl"

# %%
base_dir = base_dir_path
IMAGENET_C_data = IMAGENET_C_data_path
Subcategory_IMAGENET_C_files = Subcategory_IMAGENET_C_files_path

# %%
import matplotlib.pyplot as plt
import pickle
import seaborn as sns

# %%
corruption_levels = [1,3,5]
Imagenet_corruption_levels = ["Clean",1,3,5]

category = "noise" 
subcategory = "gaussian_noise" 

JSs_DCT_files = []

for lev in range(len(corruption_levels)):
    JSs_DCT_files.append(f"{base_dir}{Subcategory_IMAGENET_C_files}/Divergences/JSs_DCT_{category}_{subcategory}_{corruption_levels[lev]}.pkl")
    
JSs_DCT_levs = []

# load saved files
for lev in range(len(corruption_levels)):
    with open(JSs_DCT_files[lev], "rb") as fp: 
        JSs_DCT_levs.append(pickle.load(fp))
        
with open(bench_JSs_DCT_f, "rb") as fp: 
    bench_JSs_DCT = pickle.load(fp)
    
DCT_JS_boxplot_f = f"{base_dir}{Subcategory_IMAGENET_C_files}/Figures/BF/crop/fig_JSs_DCT_{category}_{subcategory}_{corruption_levels}.png"
DCT_JS_boxplot_full_f = f"{base_dir}{Subcategory_IMAGENET_C_files}/Figures/BF/full/fig_JSs_DCT_full_{category}_{subcategory}_{corruption_levels}.png"

JSs_DCT_all = []

JSs_DCT_all.append(bench_JSs_DCT)
JSs_DCT_all.append(JSs_DCT_levs[0])
JSs_DCT_all.append(JSs_DCT_levs[1])
JSs_DCT_all.append(JSs_DCT_levs[2])

fig_JS = sns.boxplot(data=JSs_DCT_all)
fig_JS.set_xticklabels(Imagenet_corruption_levels)
fig_JS.tick_params(labelsize=12)
plt.xlabel('Corruption Levels', fontsize=18)
plt.ylabel('JS', fontsize=18)
plt.ylim(0, 0.1)
################ CHANGE HERE #####################
plt.title(label = f"Clean, gaussian noise severity {corruption_levels}", fontsize=18) 
plt.tight_layout()
plt.savefig(DCT_JS_boxplot_f)

# %%
corruption_levels = [1,3,5]
Imagenet_corruption_levels = ["Clean",1,3,5]

category = "digital" 
subcategory = "contrast" 

JSs_DCT_files = []

for lev in range(len(corruption_levels)):
    JSs_DCT_files.append(f"{base_dir}{Subcategory_IMAGENET_C_files}/Divergences/JSs_DCT_{category}_{subcategory}_{corruption_levels[lev]}.pkl")
    
JSs_DCT_levs = []

# load saved files
for lev in range(len(corruption_levels)):
    with open(JSs_DCT_files[lev], "rb") as fp: 
        JSs_DCT_levs.append(pickle.load(fp))
        
with open(bench_JSs_DCT_f, "rb") as fp: 
    bench_JSs_DCT = pickle.load(fp)
    
DCT_JS_boxplot_f = f"{base_dir}{Subcategory_IMAGENET_C_files}/Figures/BF/crop/fig_JSs_DCT_{category}_{subcategory}_{corruption_levels}.png"
DCT_JS_boxplot_full_f = f"{base_dir}{Subcategory_IMAGENET_C_files}/Figures/BF/full/fig_JSs_DCT_full_{category}_{subcategory}_{corruption_levels}.png"

JSs_DCT_all = []

JSs_DCT_all.append(bench_JSs_DCT)
JSs_DCT_all.append(JSs_DCT_levs[0])
JSs_DCT_all.append(JSs_DCT_levs[1])
JSs_DCT_all.append(JSs_DCT_levs[2])

fig_JS = sns.boxplot(data=JSs_DCT_all)
fig_JS.set_xticklabels(Imagenet_corruption_levels)
fig_JS.tick_params(labelsize=12)
plt.xlabel('Corruption Levels', fontsize=18)
plt.ylabel('JS', fontsize=18)
plt.ylim(0, 0.1)
################ CHANGE HERE #####################
plt.title(label = f"Clean, contrast severity {corruption_levels}", fontsize=18) 
plt.tight_layout()
plt.savefig(DCT_JS_boxplot_f)

# %%
corruption_levels = [1,3,5]
Imagenet_corruption_levels = ["Clean",1,3,5]

category = "blur" 
subcategory = "glass_blur" 

JSs_DCT_files = []

for lev in range(len(corruption_levels)):
    JSs_DCT_files.append(f"{base_dir}{Subcategory_IMAGENET_C_files}/Divergences/JSs_DCT_{category}_{subcategory}_{corruption_levels[lev]}.pkl")
    
JSs_DCT_levs = []

# load saved files
for lev in range(len(corruption_levels)):
    with open(JSs_DCT_files[lev], "rb") as fp: 
        JSs_DCT_levs.append(pickle.load(fp))
        
with open(bench_JSs_DCT_f, "rb") as fp: 
    bench_JSs_DCT = pickle.load(fp)
    
DCT_JS_boxplot_f = f"{base_dir}{Subcategory_IMAGENET_C_files}/Figures/BF/crop/fig_JSs_DCT_{category}_{subcategory}_{corruption_levels}.png"
DCT_JS_boxplot_full_f = f"{base_dir}{Subcategory_IMAGENET_C_files}/Figures/BF/full/fig_JSs_DCT_full_{category}_{subcategory}_{corruption_levels}.png"

JSs_DCT_all = []

JSs_DCT_all.append(bench_JSs_DCT)
JSs_DCT_all.append(JSs_DCT_levs[0])
JSs_DCT_all.append(JSs_DCT_levs[1])
JSs_DCT_all.append(JSs_DCT_levs[2])

fig_JS = sns.boxplot(data=JSs_DCT_all)
fig_JS.set_xticklabels(Imagenet_corruption_levels)
fig_JS.tick_params(labelsize=12)
plt.xlabel('Corruption Levels', fontsize=18)
plt.ylabel('JS', fontsize=18)
plt.ylim(0, 0.1)
################ CHANGE HERE #####################
plt.title(label = f"Clean, glass blur severity {corruption_levels}", fontsize=18) 
plt.tight_layout()
plt.savefig(DCT_JS_boxplot_f)

# %%
corruption_levels = [1,3,5]
Imagenet_corruption_levels = ["Clean",1,3,5]

category = "weather" 
subcategory = "fog" 

JSs_DCT_files = []

for lev in range(len(corruption_levels)):
    JSs_DCT_files.append(f"{base_dir}{Subcategory_IMAGENET_C_files}/Divergences/JSs_DCT_{category}_{subcategory}_{corruption_levels[lev]}.pkl")
    
JSs_DCT_levs = []

# load saved files
for lev in range(len(corruption_levels)):
    with open(JSs_DCT_files[lev], "rb") as fp: 
        JSs_DCT_levs.append(pickle.load(fp))
        
with open(bench_JSs_DCT_f, "rb") as fp: 
    bench_JSs_DCT = pickle.load(fp)
    
DCT_JS_boxplot_f = f"{base_dir}{Subcategory_IMAGENET_C_files}/Figures/BF/crop/fig_JSs_DCT_{category}_{subcategory}_{corruption_levels}.png"
DCT_JS_boxplot_full_f = f"{base_dir}{Subcategory_IMAGENET_C_files}/Figures/BF/full/fig_JSs_DCT_full_{category}_{subcategory}_{corruption_levels}.png"

JSs_DCT_all = []

JSs_DCT_all.append(bench_JSs_DCT)
JSs_DCT_all.append(JSs_DCT_levs[0])
JSs_DCT_all.append(JSs_DCT_levs[1])
JSs_DCT_all.append(JSs_DCT_levs[2])

fig_JS = sns.boxplot(data=JSs_DCT_all)
fig_JS.set_xticklabels(Imagenet_corruption_levels)
fig_JS.tick_params(labelsize=12)
plt.xlabel('Corruption Levels', fontsize=18)
plt.ylabel('JS', fontsize=18)
plt.ylim(0, 0.1)
################ CHANGE HERE #####################
plt.title(label = f"Clean, fog severity {corruption_levels}", fontsize=18) 
plt.tight_layout()
plt.savefig(DCT_JS_boxplot_f)
